# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\saba\Downloads\student_data_clean.csv')
df
# Out:
#       Student_ID        Name  Age  Gender Department  Semester  CGPA  \
# 0           1001   Student_0   24   Other       Math         3   NaN
# 1           1002   Student_1   21  Female         EE         1  3.94
# 2           1003   Student_2   22   Other         EE         5  2.44
# 3           1004   Student_3   24    Male         EE         4  3.47
# 4           1005   Student_4   20    Male         CS         2  3.53
# ...          ...         ...  ...     ...        ...       ...   ...
# 1025        1026  Student_25   18   Other       Math         8  2.01
# 1026        1027  Student_26   21   Other        BBA         6  3.87
# 1027        1028  Student_27   19  Female       Math         1  3.64
# 1028        1029  Student_28   23    Male         EE         5  3.62
# 1029        1030  Student_29   22   Other       Math         2  3.77
#
#       Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# ...

# %% [markdown]
# shape of data

# %%
df.shape
# Out:
# (1030, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           1030 non-null   int64
#  1   Name                 1030 non-null   str
#  2   Age                  1030 non-null   int64
#  3   Gender               1030 non-null   str
#  4   Department           1030 non-null   str
#  5   Semester             1030 non-null   int64
#  6   CGPA                 979 non-null    float64
#  7   Attendance_Rate      999 non-null    float64
#  8   Scholarship          1030 non-null   bool
#  9   Admission_Date       1030 non-null   str
#  10  Midterm_Marks        1030 non-null   int64
#  11  Final_Marks          1030 non-null   int64
#  12  City                 1030 non-null   str
#  13  Study_Hours_Per_Day  1030 non-null   int64
#  14  Fees_Paid            1008 non-null   str
# dtypes: bool(1), float64(2), int64(6), str(6)
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester', 'CGPA',
#        'Attendance_Rate', 'Scholarship', 'Admission_Date', 'Midterm_Marks',
#        'Final_Marks', 'City', 'Study_Hours_Per_Day', 'Fees_Paid'],
#       dtype='str')

# %%
df.describe()
# Out:
#         Student_ID          Age     Semester        CGPA  Attendance_Rate  \
# count  1030.000000  1030.000000  1030.000000  979.000000       999.000000
# mean   1486.373786    20.971845     4.448544    3.046558        74.733734
# std     296.048992     1.996154     2.270094    0.574487        14.213981
# min    1001.000000    18.000000     1.000000    2.000000        50.000000
# 25%    1228.250000    19.000000     3.000000    2.560000        63.000000
# 50%    1485.500000    21.000000     4.000000    3.090000        74.000000
# 75%    1742.750000    23.000000     6.000000    3.545000        87.000000
# max    2000.000000    24.000000     8.000000    4.000000        99.000000
#
#        Midterm_Marks  Final_Marks  Study_Hours_Per_Day
# count    1030.000000  1030.000000          1030.000000
# mean       14.845631    24.875728             6.062136
# std         8.877224    14.492520             3.149348
# min         0.000000     0.000000             1.000000
# ...

# %%
df.head(2)
# Out:
#    Student_ID       Name  Age  Gender Department  Semester  CGPA  \
# 0        1001  Student_0   24   Other       Math         3   NaN
# 1        1002  Student_1   21  Female         EE         1  3.94
#
#    Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 0             61.0        False     2021-09-11             26           33
# 1             98.0        False     2020-01-26              0           39
#
#      City  Study_Hours_Per_Day    Fees_Paid
# 0  Multan                   10          NaN
# 1  Lahore                    5  Installment

# %%
df.tail(2)
# Out:
#       Student_ID        Name  Age Gender Department  Semester  CGPA  \
# 1028        1029  Student_28   23   Male         EE         5  3.62
# 1029        1030  Student_29   22  Other       Math         2  3.77
#
#       Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 1028             93.0         True     2022-06-26             15           27
# 1029             72.0        False     2021-08-24             26           23
#
#            City  Study_Hours_Per_Day Fees_Paid
# 1028  Islamabad                    5   Pending
# 1029  Islamabad                    9      Full

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Name                    0
# Age                     0
# Gender                  0
# Department              0
# Semester                0
# CGPA                   51
# Attendance_Rate        31
# Scholarship             0
# Admission_Date          0
# Midterm_Marks           0
# Final_Marks             0
# City                    0
# Study_Hours_Per_Day     0
# Fees_Paid              22
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#       Student_ID        Name  Age  Gender Department  Semester  CGPA  \
# 1           1002   Student_1   21  Female         EE         1  3.94
# 2           1003   Student_2   22   Other         EE         5  2.44
# 3           1004   Student_3   24    Male         EE         4  3.47
# 4           1005   Student_4   20    Male         CS         2  3.53
# 6           1007   Student_6   22  Female       Math         3  2.06
# ...          ...         ...  ...     ...        ...       ...   ...
# 1025        1026  Student_25   18   Other       Math         8  2.01
# 1026        1027  Student_26   21   Other        BBA         6  3.87
# 1027        1028  Student_27   19  Female       Math         1  3.64
# 1028        1029  Student_28   23    Male         EE         5  3.62
# 1029        1030  Student_29   22   Other       Math         2  3.77
#
#       Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID             0
# Name                   0
# Age                    0
# Gender                 0
# Department             0
# Semester               0
# CGPA                   0
# Attendance_Rate        0
# Scholarship            0
# Admission_Date         0
# Midterm_Marks          0
# Final_Marks            0
# City                   0
# Study_Hours_Per_Day    0
# Fees_Paid              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(27)

# %%
df=df.drop_duplicates()
df
# Out:
#      Student_ID         Name  Age  Gender Department  Semester  CGPA  \
# 1          1002    Student_1   21  Female         EE         1  3.94
# 2          1003    Student_2   22   Other         EE         5  2.44
# 3          1004    Student_3   24    Male         EE         4  3.47
# 4          1005    Student_4   20    Male         CS         2  3.53
# 6          1007    Student_6   22  Female       Math         3  2.06
# ..          ...          ...  ...     ...        ...       ...   ...
# 995        1996  Student_995   23    Male       Math         3  3.88
# 996        1997  Student_996   18   Other         EE         7  3.55
# 997        1998  Student_997   24  Female       Math         6  2.26
# 998        1999  Student_998   21   Other        BBA         3  2.70
# 999        2000  Student_999   23  Female        BBA         3  2.87
#
#      Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Gender distribution of students

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      308
# Other     304
# Female    292
# Name: count, dtype: int64

# %% [markdown]
# Number of students in each Department

# %%
df['Department'].value_counts()
# Out:
# Department
# Math       207
# Physics    188
# BBA        183
# CS         174
# EE         152
# Name: count, dtype: int64

# %% [markdown]
# Average Age per Department

# %%
df.groupby('Department')['Age'].mean()
# Out:
# Department
# BBA        21.131148
# CS         21.086207
# EE         20.855263
# Math       21.028986
# Physics    20.835106
# Name: Age, dtype: float64

# %% [markdown]
# Students per Semester

# %%
df['Semester'].value_counts()
# Out:
# Semester
# 3    129
# 5    121
# 4    119
# 1    118
# 7    108
# 6    107
# 8    105
# 2     97
# Name: count, dtype: int64

# %% [markdown]
# Number of students in each City

# %%
df['City'].value_counts()
# Out:
# City
# Lahore        213
# Karachi       183
# Islamabad     178
# Faisalabad    165
# Multan        165
# Name: count, dtype: int64

# %% [markdown]
# Average CGPA by Department

# %%
df.groupby('Department')['CGPA'].mean()
# Out:
# Department
# BBA        3.038579
# CS         3.064023
# EE         3.037500
# Math       3.053527
# Physics    3.024043
# Name: CGPA, dtype: float64

# %% [markdown]
# Average CGPA by Gender

# %%
df.groupby('Gender')['CGPA'].mean()
# Out:
# Gender
# Female    3.017192
# Male      3.057240
# Other     3.055428
# Name: CGPA, dtype: float64

# %% [markdown]
# Top 10 students with highest CGPA

# %%
df.sort_values('CGPA', ascending=False).head(10)
# Out:
#      Student_ID         Name  Age  Gender Department  Semester  CGPA  \
# 413        1414  Student_413   22  Female       Math         6  4.00
# 131        1132  Student_131   20    Male    Physics         2  4.00
# 595        1596  Student_595   21  Female       Math         7  3.99
# 18         1019   Student_18   19   Other        BBA         8  3.99
# 270        1271  Student_270   22  Female    Physics         8  3.99
# 334        1335  Student_334   22  Female    Physics         7  3.98
# 787        1788  Student_787   23   Other        BBA         2  3.98
# 521        1522  Student_521   22   Other         CS         6  3.98
# 221        1222  Student_221   20   Other         CS         7  3.98
# 726        1727  Student_726   22   Other         CS         1  3.97
#
#      Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 413             54.0        False     2021-10-02              5           22
# ...

# %%
pd.pivot_table(df,values='CGPA',index='Department',columns='Semester',aggfunc='mean')
# Out:
# Semester           1         2         3         4         5         6  \
# Department
# BBA         2.940435  2.816667  3.142258  3.037368  2.980000  2.930000
# CS          3.179615  3.030833  3.077500  3.299615  2.922593  2.939545
# EE          2.994500  2.788750  3.176000  3.013636  3.113182  3.271875
# Math        3.109310  2.931500  3.040345  3.130333  2.926957  3.013077
# Physics     3.048000  3.056667  2.998485  2.989545  2.909545  3.060385
#
# Semester           7         8
# Department
# BBA         3.228571  3.131111
# CS          3.035556  2.965333
# EE          2.962857  2.896522
# Math        3.219600  3.002000
# Physics     3.050870  3.104000

# %%
pd.pivot_table(df,values='CGPA',index='Department',columns='Gender',aggfunc='mean')
# Out:
# Gender        Female      Male     Other
# Department
# BBA         3.054138  3.003889  3.068679
# CS          2.977308  3.108750  3.094394
# EE          3.045833  3.020377  3.047451
# Math        3.018000  3.160339  3.004615
# Physics     2.993750  3.010588  3.075000

# %%
# eda analysis what is this 
# data alalysis and machine learnign basic step are same
# like cleaning (remane, formate correction,nullvales fixing ) data reading
# analyssi depend on purpose univariet analysis or multivariet analysis there are 
# 
# (what is gulf country), Kpi, core skill is how you question data or who you think

# %%
pd.pivot_table(df,values='Study_Hours_Per_Day',index=['Gender','Department'],columns='Semester')
# scholarship wise
# Out:
# Semester                  1         2         3         4         5         6  \
# Gender Department
# Female BBA         5.000000  5.333333  6.166667  1.000000  6.636364  7.000000
#        CS          5.400000  5.250000  7.000000  6.125000  6.125000  8.333333
#        EE          6.428571  5.000000  6.166667  7.714286  8.250000  5.500000
#        Math        6.333333  5.500000  5.000000  8.125000  6.750000  7.785714
#        Physics     6.714286  8.500000  5.583333  5.333333  8.600000  5.812500
# Male   BBA         5.900000  5.800000  7.666667  6.466667  6.000000  8.200000
#        CS          4.375000  5.200000  6.375000  4.666667  4.909091  5.400000
#        EE          5.714286  2.500000  4.500000  7.500000  7.375000  7.333333
#        Math        5.750000  7.500000  6.000000  5.714286  6.125000  4.250000
#        Physics     5.000000  6.545455  5.800000  5.000000  6.200000  5.400000
# Other  BBA         5.500000  7.428571  6.900000  3.500000  6.777778  7.571429
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID             0
# Name                   0
# Age                    0
# Gender                 0
# Department             0
# Semester               0
# CGPA                   0
# Attendance_Rate        0
# Scholarship            0
# Admission_Date         0
# Midterm_Marks          0
# Final_Marks            0
# City                   0
# Study_Hours_Per_Day    0
# Fees_Paid              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester', 'CGPA',
#        'Attendance_Rate', 'Scholarship', 'Admission_Date', 'Midterm_Marks',
#        'Final_Marks', 'City', 'Study_Hours_Per_Day', 'Fees_Paid',
#        'Admission_Year'],
#       dtype='str')

# %%
pd.pivot_table(df,values='CGPA',index=['Admission_Year'],columns=['Department'],aggfunc='mean')
# Out:
# Department           BBA        CS        EE      Math   Physics
# Admission_Year
# 2020            3.081846  3.037324  3.051967  3.039565  3.111970
# 2021            3.064412  3.118983  2.990517  3.111379  3.009359
# 2022            2.947200  3.033409  3.093333  2.973725  2.918182

# %% [markdown]
# CGPA distribution across all students

# %%
df['CGPA'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Midterm vs Final Marks correlation

# %%
df.plot.scatter(x='Midterm_Marks', y='Final_Marks')
# Out:
# <Axes: xlabel='Midterm_Marks', ylabel='Final_Marks'>

# %% [markdown]
# Average Attendance Rate per Department

# %%
df.groupby('Department')['Attendance_Rate'].mean()
# Out:
# Department
# BBA        74.836066
# CS         73.643678
# EE         75.519737
# Math       74.772947
# Physics    74.914894
# Name: Attendance_Rate, dtype: float64

# %% [markdown]
# Relationship between Study Hours and CGPA

# %%
df.plot.scatter(x='Study_Hours_Per_Day', y='CGPA')
# Out:
# <Axes: xlabel='Study_Hours_Per_Day', ylabel='CGPA'>

# %% [markdown]
# Attendance distribution across all students

# %%
df['Attendance_Rate'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# Number of students with Scholarship (True/False)

# %%
df['Scholarship'].value_counts()
# Out:
# Scholarship
# False    720
# True     184
# Name: count, dtype: int64

# %% [markdown]
# Average Fees Paid per Department

# %%
df.groupby('Department')['Fees_Paid'].value_counts()
# Out:
# Department  Fees_Paid
# BBA         Full           67
#             Pending        63
#             Installment    53
# CS          Installment    62
#             Full           58
#             Pending        54
# EE          Full           56
#             Pending        52
#             Installment    44
# Math        Full           75
#             Installment    70
#             Pending        62
# Physics     Full           74
#             Pending        70
#             Installment    44
# Name: count, dtype: int64

# %% [markdown]
# Scholarship students’ average CGPA vs Non-scholarship students

# %%
df.groupby('Scholarship')['CGPA'].mean()
# Out:
# Scholarship
# False    3.039097
# True     3.061685
# Name: CGPA, dtype: float64

# %% [markdown]
# Number of students admitted each year

# %%
df['Admission_Date'] = pd.to_datetime(df['Admission_Date'])

df['Admission_Year'] = df['Admission_Date'].dt.year

df['Admission_Year'].value_counts()
# Out:
# Admission_Year
# 2021    350
# 2020    332
# 2022    222
# Name: count, dtype: int64

# %% [markdown]
# Average CGPA per Admission Year

# %%
df.groupby('Admission_Year')['CGPA'].mean()
# Out:
# Admission_Year
# 2020    3.064036
# 2021    3.060771
# 2022    2.986351
# Name: CGPA, dtype: float64

# %% [markdown]
# Highest Midterm / Final Marks per Department

# %%
df.groupby('Department')[['Midterm_Marks', 'Final_Marks']].max()
# Out:
#             Midterm_Marks  Final_Marks
# Department
# BBA                    30           50
# CS                     30           50
# EE                     30           50
# Math                   30           50
# Physics                30           50

# %% [markdown]
# Students with failing grades

# %%
df[(df['CGPA'] < 2.0) | (df['Final_Marks'] < 20)]
# Out:
#      Student_ID         Name  Age  Gender Department  Semester  CGPA  \
# 3          1004    Student_3   24    Male         EE         4  3.47
# 4          1005    Student_4   20    Male         CS         2  3.53
# 7          1008    Student_7   24    Male    Physics         7  3.74
# 8          1009    Student_8   19  Female    Physics         6  3.05
# 10         1011   Student_10   24    Male         EE         7  3.29
# ..          ...          ...  ...     ...        ...       ...   ...
# 994        1995  Student_994   18    Male    Physics         8  3.24
# 995        1996  Student_995   23    Male       Math         3  3.88
# 996        1997  Student_996   18   Other         EE         7  3.55
# 998        1999  Student_998   21   Other        BBA         3  2.70
# 999        2000  Student_999   23  Female        BBA         3  2.87
#
#      Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# ...

# %% [markdown]
# Compare Midterm vs Final Marks per Semester

# %%
df.groupby('Semester')[['Midterm_Marks', 'Final_Marks']].mean()
# Out:
#           Midterm_Marks  Final_Marks
# Semester
# 1             14.296610    24.635593
# 2             14.639175    27.195876
# 3             13.860465    23.790698
# 4             15.344538    25.613445
# 5             15.438017    26.314050
# 6             15.121495    23.663551
# 7             15.222222    24.453704
# 8             14.266667    23.409524
